# %%
import yaml

def get_config():    
    with open("../config.yaml", "r") as stream:
        return yaml.safe_load(stream)
    
config = get_config()

lastfm_api_key = config.get("lastfm").get("api_key")

# %%
import requests
from bs4 import BeautifulSoup

def get_track_info(artist, track):
    url = f"https://ws.audioscrobbler.com/2.0/?method=track.getInfo&api_key={lastfm_api_key}&artist={artist}&track={track}&format=json"
    response = requests.get(url)
    return response.json()

def get_track_eras(url):
    markup = requests.get(url).text
    soup = BeautifulSoup(markup, "html.parser")
    eras = soup.find_all("li", class_="era")
    return [era.text.lower().strip().replace(" ", "-") for era in eras]

def filter_eras(eras):
    blacklist = ["piano", "composers"]

    return list(set([era for era in eras if era not in blacklist]))

track_info = get_track_info("Franz Schubert", "Sonata for Piano No. 17 in D, D850")
print(track_info["track"])

track_eras = get_track_eras(track_info["track"]["url"])
print(track_eras)

filtered_eras = filter_eras(track_eras)
print(filtered_eras)
# Out:
# {'name': 'Sonata for Piano No. 17 in D, D850', 'url': 'https://www.last.fm/music/Franz+Schubert/_/Sonata+for+Piano+No.+17+in+D,+D850', 'duration': '0', 'streamable': {'#text': '0', 'fulltrack': '0'}, 'listeners': '316', 'playcount': '1029', 'artist': {'name': 'Franz Schubert', 'mbid': 'f91e3a88-24ee-4563-8963-fab73d2765ed', 'url': 'https://www.last.fm/music/Franz+Schubert'}, 'toptags': {'tag': []}}
# ['classical', 'romantic', 'piano', 'composers', 'classical', 'romantic', 'piano']
# ['classical', 'romantic']

# %%
import pandas as pd

raw_metadata = pd.read_csv("../data/raw/metadata.csv")
clean_metadata = pd.read_csv("../data/clean/metadata.csv")

joined_metadata = pd.merge(raw_metadata, clean_metadata, on="midi_filename", how="inner")

display(joined_metadata.head())
# Out:
#    canonical_composer                canonical_title     split_x  year  \
# 0          Alban Berg                   Sonata Op. 1       train  2017
# 1  Alexander Scriabin  24 Preludes Op. 11, No. 13-24       train  2004
# 2  Alexander Scriabin               3 Etudes, Op. 65  validation  2006
# 3  Alexander Scriabin              5 Preludes, Op.15  validation  2009
# 4  Alexander Scriabin               Entragete, Op.63        test  2009
#
#                                        midi_filename  \
# 0  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 1  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...
# 2  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...
# 3  2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MI...
# 4  2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MI...
#
#                                       audio_filename  duration_x     split_y  \
# 0  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...  464.649433       train
# 1  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  872.640588       train
# 2  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  397.857508  validation
# 3  2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MI...  400.557826  validation
# 4  2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MI...  163.745830        test
#
#    duration_y
# 0  464.649433
# 1  872.640588
# 2  397.857508
# 3  400.557826
# 4  163.745830

# %%
import time

def apply_eras(row):
    composer = row["canonical_composer"].replace("#", "%23")
    title = row["canonical_title"].replace("#", "%23")

    filtered_eras = []
    for i in range(3):
        if len(filtered_eras) > 0: break

        try:
            track_info = get_track_info(composer, title)
            if "track" not in track_info: return []

            track_eras = get_track_eras(track_info["track"]["url"])
            filtered_eras = filter_eras(track_eras)
        except:
            time.sleep(1)
            continue


    return filtered_eras

for i in range(0, len(clean_metadata), 50):
    batch = joined_metadata.iloc[i:i + 50]
    
    time.sleep(1)
    for idx, row in batch.iterrows():
        clean_metadata.loc[idx, "eras"] = "+".join(apply_eras(row))
    
    clean_metadata.to_csv("../data/clean/eras.csv", index=False)

# %%
import requests
from bs4 import BeautifulSoup

def get_track_info_allmusic(artist, track):
    artist = artist.replace(" ", "%20")
    track = track.replace(" ", "%20")

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"
    }
    url = f"https://www.allmusic.com/search/all/{artist}%2C%20{track}"
    markup = requests.get(url, headers=headers).text
    soup = BeautifulSoup(markup, "html.parser")
    
    composition_url = soup.select_one("#pageContainer .composition .title a").attrs["href"]
    composition_markup = requests.get(composition_url, headers=headers).text
    composition_soup = BeautifulSoup(composition_markup, "html.parser")
    
    result = "classical"
    try:
        period = composition_soup.select_one(".period div")
        print(period)
        if period: result = period.text.strip().lower()
        else:
            genre = composition_soup.select_one(".genre div")
            print(genre)
            if genre: result = genre.text.strip().lower()
    except:
        result = "classical"

    return result

def get_eras_allmusic(row):
    composer = row["canonical_composer"].replace("#", "%23")
    title = row["canonical_title"].replace("#", "%23")

    try:
        return get_track_info_allmusic(composer, title)
    except Exception as e:
        print(e)
        print(f"Failed to get info for {composer} - {title}")


for i in range(0, len(clean_metadata), 50):
    batch = joined_metadata.iloc[i:i + 50]
    
    time.sleep(1)
    for idx, row in batch.iterrows():
        if not clean_metadata.loc[idx, "eras"]:
            clean_metadata.loc[idx, "eras"] = get_eras_allmusic(row)
    
clean_metadata.to_csv("../data/clean/eras.csv", index=False)
# Out:
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Alexander Scriabin - Entragete, Op.63
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Alexander Scriabin - Etude Op. 42, Nos. 4 & 5
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Alexander Scriabin - Etudes from Op.8
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Alexander Scriabin - Fragilite, Op.51
# <div>
#                                             Post-Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Alexander Scriabin - Two Impromptus, Op. 14 (Complete)
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Carl Maria von Weber - Sonata No. 1, 2nd, 3rd and 4th movements
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Charles Gounod / Franz Liszt - Faust Waltz
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - "Feux d'artifice" from Book II
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - "Images", Series I
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - "Les collines d'Anacapri" from Preludes, Book I
# None
# <div>
# <a href="https://www.allmusic.com/genre/chamber-music-ma0000004500">Chamber Music</a>, <a href="https://www.allmusic.com/genre/classical-ma0000002521">Classical</a> </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - "Voiles" from Preludes, Book I
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Estampes (Complete)
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Etude No. 6, Book I, "Pour les huits doigts"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Etude No. 7 "Study in Chromatic Steps"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Four Preludes
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Image (Book II)
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Images, Book I, "Reflets dans l'eau"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Images, Book II, "Poissons d'or"
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Prelude No. 24 "Fireworks"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Prelude No. 6, Book I, "Des pas sur la neige"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Prelude No. 7, Book II, La terrasse des audiences du clair de lune
# <div>
#                                             Modern                                    </div>
# <div>
#                                             Contemporary                                            Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Preludes, Book II, III - La puerta del vino
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Preludes, Book II, L 123, IV. «Les fées sont d'exquises danseuses»
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Preludes, Book II, VII - La terasse des audiences du clair de lune
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - PreludesBII/7-12
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Claude Debussy - Three Etudes
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for César Franck - Prel./Chor./Fug.
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for César Franck - Prelude, Fugue et Variation, Op. 18, Arrangement Delle Vigne
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Baroque                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Baroque                                    </div>
# <div>
#                                             Baroque                                    </div>
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Domenico Scarlatti - Two Sonatas
# <div>
#                                             Baroque                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Edvard Grieg - Lyric Piece in E Minor, “Valse-Impromptu,” Op. 47 No.1
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Felix Mendelssohn - Variations Seriouses, Op. 54
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Baroque                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Muzio Clementi - Sonata Op. 24/2
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Modern                                    </div>
# <div>
#                                             Romantic                                            Post-Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Niccolò Paganini / Franz Liszt - Etude No. 6 in A Minor
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Nikolai Medtner - Three Fairy Tales "Skazki" from Op. 34
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Nikolai Medtner - Two Fairy Tales
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Nikolai Rimsky-Korsakov / Sergei Rachmaninoff - The Flight of the Bunble-Bee
# <div>
#                                             Post-Romantic                                            Modern                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky - The Seasons, Op. 37a (Selections)
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - Andante Maestoso from "Nutcracker Suite"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - Concert Suite from the Ballet Nutcracker
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - Concert Suite from the Nutcracker
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - Intermezzo from "Nutcracker Suite"
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - March from "Nutcracker Suite
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Mikhail Pletnev - Nutcracker Suite
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Sergei Rachmaninoff - Lullaby
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Pyotr Ilyich Tchaikovsky / Sergei Rachmaninoff - Lullaby Op. 16, No. 1
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Richard Wagner / Franz Liszt - IsoldasLiebestod
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Richard Wagner / Franz Liszt - Isolde's Liebestod
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Robert Schumann - Kreisleriana, Op. 16 (1st edition) (Complete)
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Robert Schumann - Kreisleriana, Op. 16 (Complete)
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Robert Schumann - Sonata F%23 Minor
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Robert Schumann / Franz Liszt - Widmung
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Corelli Var.Op42
# <div>
#                                             Classical                                            Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Elegy Op. 3, No. 1
# <div>
#                                             Modern                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                            Post-Romantic                                    </div>
# <div>
#                                             Modern                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Moment Musical, Op. 16, No.4
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Modern                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Polka de "W.R."
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Prelude Op. 23/4
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Prelude Op. 32/5
# <div>
#                                             Classical                                            Romantic                                    </div>
# <div>
#                                             Romantic                                    </div>
# <div>
#                                             Classical                                            Romantic                                    </div>
# <div>
#                                             Classical                                            Romantic                                    </div>
# <div>
#                                             Baroque                                    </div>
# <div>
#                                             Classical                                            Romantic                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff - Sonata in B-flat Minor, Op.36
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff / György Cziffra - Flight of B.B.
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Sergei Rachmaninoff / Vyacheslav Gryaznov - Italian Polka
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Fantasy in C Min
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Nine Variations, K. 264
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K 333, First Movement
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K. 281, First Movement
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K. 333, 1st mov.
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K. 333, I. Allegro
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K. 570, 1st mov.
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in B-flat Major, K.281
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in C Minor K457, First Movement
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in D-Major, K. 311, First Movement
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in F K332
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# <div>
#                                             Classical                                    </div>
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Sonata in F Major, K533/K494
# 'NoneType' object has no attribute 'attrs'
# Failed to get info for Wolfgang Amadeus Mozart - Twelve Variations, K179 (189a)

# %%
top_eras = ["post-romantic", "romantic", "baroque", "impressionist", "modern", "classical"]

eras_df = pd.read_csv("../data/clean/eras.csv")
eras_df.head()
# Out:
#         split                                      midi_filename    duration  \
# 0       train  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...  464.649433
# 1       train  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  872.640588
# 2  validation  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  397.857508
# 3  validation  2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MI...  400.557826
# 4        test  2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MI...  163.745830
#
#                                                 tags
# 0  contemporary-classical+20th-century-classical+...
# 1                                      post-romantic
# 2                composer+classical+russian+romantic
# 3                composer+classical+russian+romantic
# 4                                                NaN

# %%
for i, row in eras_df.iterrows():
    if not row["eras"]: continue

    eras = str(row["eras"]).split("+")

    for era in top_eras:
        if era in eras or era in str(row["eras"]):
            eras_df.loc[i, "eras"] = era.strip().lower()
            break

eras_df.to_csv("../data/clean/eras.csv", index=False)

# %%
eras_df["eras"].value_counts()
# Out:
# tags
# romantic         432
# baroque           74
# classical         40
# modern            18
# impressionist     12
# post-romantic     11
# contemporary       2
# Name: count, dtype: int64

# %%
eras_df.dropna(subset=["eras"], inplace=True)
eras_df["eras"].isna().sum()
# Out:
# 0
